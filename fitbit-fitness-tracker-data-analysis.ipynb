# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import time

# %%
df = pd.read_csv('/kaggle/input/fitbit/mturkfitbit_export_4.12.16-5.12.16/Fitabase Data 4.12.16-5.12.16/dailyActivity_merged.csv')

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %%
df.isna().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %%
df.Id.nunique()
# Out:
# 33

# %%
new_columns = ['Id' , 'ActivityDate' , 'TotalSteps' , 'VeryActiveMinutes' , 'FairlyActiveMinutes' , 'LightlyActiveMinutes' , 'SedentaryMinutes' ,'Calories' ]
df = df[new_columns]
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366    4/12/2016       13162                 25
# 1    1503960366    4/13/2016       10735                 21
# 2    1503960366    4/14/2016       10460                 30
# 3    1503960366    4/15/2016        9762                 29
# 4    1503960366    4/16/2016       12669                 36
# ..          ...          ...         ...                ...
# 935  8877689391     5/8/2016       10686                 17
# 936  8877689391     5/9/2016       20226                 73
# 937  8877689391    5/10/2016       10733                 18
# 938  8877689391    5/11/2016       21420                 88
# 939  8877689391    5/12/2016        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df.rename( {'ActivityDate':'date'}, axis =1, inplace = True)

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366  4/12/2016       13162                 25
# 1    1503960366  4/13/2016       10735                 21
# 2    1503960366  4/14/2016       10460                 30
# 3    1503960366  4/15/2016        9762                 29
# 4    1503960366  4/16/2016       12669                 36
# ..          ...        ...         ...                ...
# 935  8877689391   5/8/2016       10686                 17
# 936  8877689391   5/9/2016       20226                 73
# 937  8877689391  5/10/2016       10733                 18
# 938  8877689391  5/11/2016       21420                 88
# 939  8877689391  5/12/2016        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df['Total_Minutes'] = df[['VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes', 'SedentaryMinutes']].sum(axis=1)
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366  4/12/2016       13162                 25
# 1    1503960366  4/13/2016       10735                 21
# 2    1503960366  4/14/2016       10460                 30
# 3    1503960366  4/15/2016        9762                 29
# 4    1503960366  4/16/2016       12669                 36
# ..          ...        ...         ...                ...
# 935  8877689391   5/8/2016       10686                 17
# 936  8877689391   5/9/2016       20226                 73
# 937  8877689391  5/10/2016       10733                 18
# 938  8877689391  5/11/2016       21420                 88
# 939  8877689391  5/12/2016        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df['Total_hours'] = round(df['Total_Minutes'] / 60)

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366  4/12/2016       13162                 25
# 1    1503960366  4/13/2016       10735                 21
# 2    1503960366  4/14/2016       10460                 30
# 3    1503960366  4/15/2016        9762                 29
# 4    1503960366  4/16/2016       12669                 36
# ..          ...        ...         ...                ...
# 935  8877689391   5/8/2016       10686                 17
# 936  8877689391   5/9/2016       20226                 73
# 937  8877689391  5/10/2016       10733                 18
# 938  8877689391  5/11/2016       21420                 88
# 939  8877689391  5/12/2016        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df['Total_hours'].max()
# Out:
# 24.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   date                  940 non-null    object
#  2   TotalSteps            940 non-null    int64
#  3   VeryActiveMinutes     940 non-null    int64
#  4   FairlyActiveMinutes   940 non-null    int64
#  5   LightlyActiveMinutes  940 non-null    int64
#  6   SedentaryMinutes      940 non-null    int64
#  7   Calories              940 non-null    int64
#  8   Total_Minutes         940 non-null    int64
#  9   Total_hours           940 non-null    float64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 73.6+ KB

# %% [markdown]
# # column date is object so i will convert it to datetime

# %%
df['date']= pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   date                  940 non-null    datetime64[ns]
#  2   TotalSteps            940 non-null    int64
#  3   VeryActiveMinutes     940 non-null    int64
#  4   FairlyActiveMinutes   940 non-null    int64
#  5   LightlyActiveMinutes  940 non-null    int64
#  6   SedentaryMinutes      940 non-null    int64
#  7   Calories              940 non-null    int64
#  8   Total_Minutes         940 non-null    int64
#  9   Total_hours           940 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(8)
# memory usage: 73.6 KB

# %% [markdown]
# # I will add a new column that will have the days so that we know the most active days

# %%
df['Day_Of_Week'] = df['date'].dt.day_name()

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-04-12       13162                 25
# 1    1503960366 2016-04-13       10735                 21
# 2    1503960366 2016-04-14       10460                 30
# 3    1503960366 2016-04-15        9762                 29
# 4    1503960366 2016-04-16       12669                 36
# ..          ...        ...         ...                ...
# 935  8877689391 2016-05-08       10686                 17
# 936  8877689391 2016-05-09       20226                 73
# 937  8877689391 2016-05-10       10733                 18
# 938  8877689391 2016-05-11       21420                 88
# 939  8877689391 2016-05-12        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %% [markdown]
# # visualizations

# %%
plt.figure(figsize =( 8 , 4))
plt.hist(df.Day_Of_Week,bins = 8 ,color = 'r' , width = .5 )
plt.xlabel('Day_Of_Week')
plt.ylabel('freq')
plt.title('freq by day of week')
plt.show()

# %%
df['Day_Of_Week'] = pd.to_numeric(df['Day_Of_Week'], errors='coerce')

# %%
df.corr()
# Out:
#                             Id      date  TotalSteps  VeryActiveMinutes  \
# Id                    1.000000 -0.015571    0.185721           0.303608
# date                 -0.015571  1.000000   -0.043931          -0.044200
# TotalSteps            0.185721 -0.043931    1.000000           0.667079
# VeryActiveMinutes     0.303608 -0.044200    0.667079           1.000000
# FairlyActiveMinutes   0.051158  0.025305    0.498693           0.312420
# LightlyActiveMinutes -0.098754 -0.049142    0.569600           0.051926
# SedentaryMinutes     -0.043319 -0.095298   -0.327484          -0.164671
# Calories              0.396671 -0.092843    0.591568           0.615838
# Total_Minutes        -0.048274 -0.131693   -0.017285          -0.018244
# Total_hours          -0.048140 -0.132148   -0.018152          -0.021064
# Day_Of_Week                NaN       NaN         NaN                NaN
#
#                       FairlyActiveMinutes  LightlyActiveMinutes  \
# ...

# %%
sns.heatmap(df.corr() , fmt='.2g', annot=True, linewidths = .10  )
# Out:
# <Axes: >

# %% [markdown]
# # Very Active Minutes and Total Steps has more to do with Calories

# %%
plt.figure(figsize =( 8 , 4))
plt.scatter(df.TotalSteps , df.Calories, c=df.Calories )

plt.xlabel('TotalSteps')
plt.ylabel('Calories')
plt.title('relation between Calories & TotalSteps ')
plt.show()

# %%
plt.figure(figsize =( 8 , 4))
plt.scatter(df.TotalSteps , df.Calories, c=df.Calories )

median_cal = df['Calories'].median()
median_steps = df['TotalSteps'].median()

plt.axhline(median_cal , color='b', label ='median of calories' )
plt.axvline(median_steps , color='r', label ='median of TotalSteps' )

plt.xlabel('TotalSteps')
plt.ylabel('Calories')
plt.title('relation between Calories & TotalSteps ')
plt.legend()
plt.show()

# %%
plt.figure(figsize=((10,6)))
plt.scatter(df['Total_hours'] , df['Calories']  , c =df['Calories'] )
med_num_of_hours = df['Total_hours'].median()
med_num_of_Calories = df['Calories'].median()
plt.axhline(med_num_of_Calories ,  c = 'b' , label = 'med_of_Calories')
plt.axvline(med_num_of_hours ,  c = 'r' , label = 'med_of_hours')
plt.title('relation Total_Hours & Calories')
plt.xlabel('Total_hours')
plt.ylabel('Calories')
plt.legend()
plt.show()
